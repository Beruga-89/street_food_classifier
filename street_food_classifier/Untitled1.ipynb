# %%
# Speichere das Dashboard und starte:
from ml_command_dashboard import launch_dashboard

# Vollständiges interaktives Dashboard
dashboard = launch_dashboard()

# Oder schnelle Optionen:
from ml_command_dashboard import quick_experiment, quick_comparison

# Einzelnes schnelles Experiment
experiment_result = quick_experiment()

# Schneller Model-Vergleich
comparison_result = quick_comparison()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 from ml_command_dashboard import launch_dashboard
#       4 # Vollständiges interaktives Dashboard
# ----> 5 dashboard = launch_dashboard()
#       7 # Oder schnelle Optionen:
#       8 from ml_command_dashboard import quick_experiment, quick_comparison
#
# File D:\Neural_Networks\Kaggle\street_food_classifier\ml_command_dashboard.py:676, in launch_dashboard()
#     674 def launch_dashboard():
#     675     """Startet das ML Dashboard mit automatischem Fix."""
# --> 676     dashboard = MLCommandDashboard()
#     677     dashboard.run_dashboard()
#     678     return dashboard
#
# File D:\Neural_Networks\Kaggle\street_food_classifier\ml_command_dashboard.py:44, in MLCommandDashboard.__init__(self)
#      41 self.session_dir.mkdir(parents=True, exist_ok=True)
#      43 # Apply automatic trainer fix
# ...

# %%
# Das wird jetzt funktionieren:
from ml_command_dashboard import launch_dashboard

dashboard = launch_dashboard()
# Out:
# ✅ Control Center Imports erfolgreich
# 🎮 ML CONTROL CENTER INITIALISIERT
# ...
# 🔍 SCANNE 3 MODELS...
# ✅ 3 Models registriert
#
# 🎮 ML CONTROL CENTER BEREIT!
#
# === BASIC OPERATIONS ===
# ml.status()                              # Vollständiger Status
# ml.train('resnet18', epochs=10)          # Training
# ml.evaluate('best_f1_model.pth')         # Evaluation
#
# === QUICK FUNCTIONS (kompatibel) ===
# quick_status()                           # Quick Status
# quick_train('resnet18', epochs=5)        # Quick Training
# quick_evaluate('best_f1_model.pth')      # Quick Evaluation
#
# === ALLES VON EINEM ORT! ===
#
# 🎮 ML COMMAND DASHBOARD INITIALIZED
# ...
# 📁 Session Directory: outputs\dashboard\session_20250531_200445
# 🔧 Trainer API Fix: READY
# 🎮 Welcome to ML Command Center Dashboard!
#
# 🎮 ML COMMAND CENTER DASHBOARD
# ...
# ✅ Professional Training API: READY
#
# 1. 🔬 Quick Experiment (Single Model)
# 2. 📊 Model Comparison Study
# 3. 🎯 Hyperparameter Optimization
# 4. 📈 Performance Analysis
# ...
